# %%
import os;os.chdir("../")

# %%
import Match
import pandas as pd

# %%
match_analysis = Match.Match(season = '2017/2018', competition = 'La Liga', home = 'Real Madrid', away = 'Barcelona')

# %% [markdown]
# ### Goal Plays

# %%
match_analysis.show_goals(figsize=8)

# %% [markdown]
# ### Shots

# %%
match_analysis.player_shots('Benzema')

# %%
match_analysis.player_shots('Ronaldo')

# %%
match_analysis.team_shots('Real Madrid')

# %%
match_analysis.player_shots('Suárez')

# %%
match_analysis.player_shots('Messi')

# %%
match_analysis.test_player_shots('Messi')

# %% [markdown]
# ### Fouls

# %%
match_analysis.player_fouls('Ramos')

# %%
match_analysis.test_player_fouls('Ramos')

# %% [markdown]
# ### Passes

# %%
match_analysis.player_passes('Marcelo', arrows = True)

# %%
match_analysis.player_passes('Kroos', arrows = True)

# %% [markdown]
# ### Crosses

# %%
match_analysis.player_crosses('Marcelo', arrows = True)

# %%
match_analysis.player_crosses('Marcelo', arrows = False)

# %% [markdown]
# ### Ball Recoveries

# %%
match_analysis.player_recoveries("Sergi Roberto")

# %%
match_analysis.test_player_recoveries("Sergi Roberto")

# %% [markdown]
# ### Dispossessions

# %%
match_analysis.player_dispossessions("Suárez")

# %%
match_analysis.test_player_dispossessions("Suárez")

# %% [markdown]
# ### Dribbles

# %%
match_analysis.player_dribbles("Messi")

# %%
match_analysis.test_player_dribbles("Messi")

# %% [markdown]
# ### Player Carries

# %%
match_analysis.player_carries("Carvajal")

# %%
match_analysis.test_player_carries("Carvajal")

# %% [markdown]
# ### Clearances

# %%
match_analysis.player_clearances("Alba")

# %%
match_analysis.test_player_clearances("Alba")

# %% [markdown]
# ### Zones of action

# %%
match_analysis.player_actions("Kroos")

# %%
match_analysis.player_actions("Marcelo")

# %%
match_analysis.player_actions("Luka")

# %%
match_analysis.player_actions("Ronaldo")

# %%
match_analysis.player_actions("Bale")

# %%
match_analysis.player_actions("Sergi Roberto")

# %% [markdown]
# ### Fouls Won

# %%
match_analysis.player_fouls_won("Luka")

# %%
match_analysis.test_player_fouls_won("Luka")

# %% [markdown]
# ### Player xG

# %%
match_analysis.player_xg("Bale")
# Out:
#           pred shot_outcome_name  minute  pred_cumsum
# 3516  0.443980             Saved      77     0.443980
# 3571  0.054922             Saved      78     0.498901
